# %% [markdown]
# # Job Listings API Example
# This pipeline shows how to use Indexical's `navigate`,`navigate-many` and `extract` actions to find a company's careers page from the landing page, open up each individual job listing, and pull the `job_title`, `job_description`, `salary`, and whether the job is `remote` for each role.

# %% [markdown]
# ### Setup
# In this section, we'll set up the environment to start using Indexical's API by importing the necessary libraries and saving the API key. Start by inputting your API key below. You can generate an API key from the Indexical console by selecting `Keys` and then hitting `New API Key`.

# %%
import requests
import json

# %%
API_KEY="<REPLACE WITH YOUR API_KEY>"

# %% [markdown]
# ### Add Pipeline
# To create scalable data extraction workflows, Indexical allows you to construct a pipeline of high-level steps that describe how to go from a URL / query to clean, structured data. Each step contains an `action` that is tied to a task-specific agent on our end, as well as a natural language `goal` to instruct the agent. We'll start by importing the `job_listings.json` file as our pipeline and printing it below.
#
# This pipeline will find a company's careers page from the landing page, open up each individual job listing, and pull the `job_title`, `job_description`, `salary`, and whether the job is `remote` for each role. Indexical uses [JSON Schema](https://json-schema.org/) for describing what fields of data to pull. Note that you can edit the schema to pull more or less information based on your use case. For each of the  items, you should input the name, field type, as well as a natural language description to help the LLM identify what information to pull from the page.

# %%
file_path="pipelines/job_listings.json"
with open(file_path, 'r') as file:
    pipeline_steps = json.load(file)
    print(json.dumps(pipeline_steps, indent=4))
# Out:
# {
#     "name": "job_listings",
#     "steps": [
#         {
#             "action": "navigate",
#             "goal": "Find a page listing open jobs/positions at the company. Make sure at least 2 job postings are listed on the page"
#         },
#         {
#             "action": "navigate-many",
#             "goal": "Find the dedicated pages for each individual job listings, with all the details.",
#             "retries": 2,
#             "validation": {
#                 "size": {
#                     "min": 2
#                 }
#             }
#         },
#         {
#             "action": "extract",
#             "goal": "Structure the information about the current job listing.",
#             "schema": {
#                 "job_description": "$mainContent",
#                 "company": {
#                     "description": "the company posting the role",
#                     "type": "string"
#                 },
#                 "remote": {
#                     "description": "Whether this job is fully remote or it requires on site",
#                     "type": "boolean"
#                 },
#                 "salary": {
#                     "description": "the salary range of the role, if described",
#                     "type": "string"
#                 },
#                 "summary": {
#                     "description": "A small summary of the job. Limit to 1 - 2 sentences",
#                     "type": "string"
#                 },
#                 "title": {
#                     "description": "The job title",
#                     "type": "string"
#                 }
#             }
#         }
#     ]
# }

# %% [markdown]
# Now, we'll call Indexical's `pipelines` API endpoint to save that pipeline for use in future data extraction workflows Each API request requires the header with `x-api-key`, and you include the JSON pipeline as the API body.

# %%
response = requests.post("https://app.indexical.dev/pipelines",
                          headers={'x-api-key': API_KEY}, 
                          json=pipeline_steps)

if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
else:
    print(response.status_code)

# %% [markdown]
# ### Run data extraction job
# Once you've saved your pipeline, you can then run that workflow on any set ofwebsites / queries through that pipeline. Indexical will use AI to handle the process of mapping that pipeline to relevant selectors and information on each page, gathering and transforming the website into a clean, standardized schema of your choosing.
#
# In this case, I will run the `job_listings` pipeline and input 2 websites at run-time.

# %%
response = requests.post("https://app.indexical.dev/runs",
                          headers={'x-api-key': API_KEY}, 
                          json={
                              "name" : "job_listings", 
                              "urls" : ["https://loop.com/", "https://www.merge.dev/"], 
                              "proxiesEnabled" : True
                          })

# %% [markdown]
# By default, the `runs` endpoint will run the data extraction pipeline and return the results asynchronously (either available for download on the developer console or transmitted to a subscriber URL via webhooks). As a response, the `runs` endpoint will return both the `pipelineID` and `runID`.

# %%
if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
    run_id = data['id']
    print(data)
else:
    print(response.status_code)
# Out:
# {'pipeline': 1017, 'id': 1553}

# %% [markdown]
# ### Getting Results
# To get the results programmatically, you can either use [webhooks](https://docs.indexical.dev/runs) or use the `outputs` endpoint. Simply call `https://app.indexical.dev/runs/:runId/outputs` with the `runID` returned by the `runs` endpoint.

# %%
output_endpoint = "https://app.indexical.dev/runs/" + str(run_id) + "/outputs"
response = requests.get(output_endpoint,
                          headers={'x-api-key': API_KEY})

# %% [markdown]
# By default, the results will be a JSON file with 2 keys `results` and `errors`. Each key will contain an array of results. Each result has a `seed` query/URL, the final `url` from which Indexical extracted the information, as well as a `data` key which has all of the data specified in the pipeline. If Indexical was not able to find information on the page that maps to a specific element, it will either return `NULL` or not output that key.

# %%
if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
    print(json.dumps(data, indent=4))
else:
    print(response.status_code)
# Out:
# {
#     "results": [
#         {
#             "id": 7594536,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/5224737004",
#             "data": {
#                 "title": "Business Analyst",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "Loop is hiring an analyst to support the business as it grows. This role will work directly with customer success, product, engineering and business operations to build key reporting, validate Loop\u2019s technology outputs, and support client demos.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout the Role\n\nLoop is hiring an analyst to support the business as it grows. This role will\nwork directly with customer success, product, engineering and business\noperations to build key reporting, validate Loop\u2019s technology outputs, and\nsupport client demos. This role will work cross functionally and on various\nprojects to drive customer value and adoption of Loop\u2019s automation technology.\n\nAs part of Business Operations, this role will support all internal operations\nat Loop while also partnering closely with product and business leaders to\naccelerate progress on our biggest bets.\n\nKey Responsibilities\n\n * Partner with data science, customer success and business operations to\n   proactively solve problems and ensure Loop is built to scale\n * Support key business partners as a jack of all trades to accelerate growth\n   and customer delivery in Loop\u2019s most important business segments\n * Serve as the internal voice of the customer bringing insights from customer\n   success to product and bridging gaps for features that are yet to be built\n * Build and maintain reporting and inputs that feed Loop\u2019s automation and\n   calculation engines using Excel, SQL, Python and other tools\n\nAbout You\n\n * You have a college degree with a quantitative background in analytics,\n   finance, or economics\n * You have 2 years of work experience in management consulting, data analysis\n   or other quantitative fields\n * You have advanced excel skills and SQL, Python or other programming skills\n * You balance an eagerness to learn with the ability to execute\u00a0\n * You\u2019re a team player and excited about the opportunity to be an early\n   employee at a fast-paced, fast-growing company\n * You have the ability to travel up to 20%\n * This is a hybrid role based in Chicago with the expectation to be in the\n   office\n\nBenefits & Perks\n\n * Premium Medical, Dental, and Vision Insurance plans, with premiums covered\n   100% for you\n * Unlimited PTO\n * 401k plan\n * Commuter benefits for parking/transit\n * Generous professional development budget to feed your curiosity\n * Physical and Mental fitness subsidies for yoga, meditation, gym etc.\n\nusechatgpt init success"
#             },
#             "created_at": "2024-07-13 01:29:24.657382"
#         },
#         {
#             "id": 7594537,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4830548004",
#             "data": {
#                 "title": "Software Engineer, Full-Stack",
#                 "remote": false,
#                 "salary": "Base pay 120k - 190k",
#                 "company": "Loop",
#                 "summary": "As a full-stack engineer, you will work closely with founders and customers to understand and solve their logistics billing and payment pain points. You will help define the product and ship features that directly impact our customers.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n(https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout You\nAs a full-stack engineer, you will work closely with founders and customers to\nunderstand and solve their logistics billing and payment pain points. You will\nhelp define the product and ship features that directly impact our customers.\nYou will face and solve many complex technical challenges while you receive\nguidance and feedback from the team. You will shape the Loop DNA and define how\nwe grow as a company.\n\nResponsibilities\n\n * Work cross-functionally with product, design, and sales to understand\n   requirements and ship thoughtful solutions.\n\n * Write high-quality code optimized for extensibility.\n\n * Engage in code reviews to maintain a high bar of engineering excellence.\n\n * Lead discussions and documentation to communicate and arrive at the best\n   technical design.\n\n * Work across different components boundaries, from frontend to backend, and\n   even infrastructure layers.\n\n * Promote better practices and share technical knowledge across the team.\n\n * Help grow Loop through deliberate feedback on product, process, and culture.\n\nQualifications\n\n * Five years of software engineering experience.\n\n * Experience with TypeScript and tools such as GraphQL, Relay, React, and\n   Node.js.\n\n * Experience working at early-stage companies where you shipped products end to\n   end and wore many hats.\n\nUnder the Hood\n\n * Infrastructure: AWS, CDK, Fargate ECS\n\n * Backend: TypeScript, Node.js, Prisma, NestJS, PostgreSQL, Redis,\n   Elasticsearch, GraphQL\n\n * Frontend: TypeScript, React, Relay, Ant Design, Vite, GraphQL\n\nCompensation\n\n * Base pay 120k - 190k\n\nBenefits & Perks\n\n * Premium Medical, Dental, and Vision Insurance plans\n\n * Insurance premiums covered 100% for you\n\n * Unlimited PTO\n\n * Fireside chats with industry leading keynote speakers\n\n * Off-sites in locales such as Napa and Tahoe\n\n * Generous professional development budget to feed your curiosity\n\n * Physical and Mental fitness subsidies for yoga, meditation, gym, or ski\n   memberships\n\nWhy you should join Loop? - https://whyyoushouldjoin.substack.com/p/loop"
#             },
#             "created_at": "2024-07-13 01:29:25.235182"
#         },
#         {
#             "id": 7594538,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4884174004",
#             "data": {
#                 "title": "Implementation Manager",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "We are looking for an Implementation Manager to collaborate across Sales, Pre-Sales, Engineering and Customer Success to help provide clients with a seamless onboarding experience. The Implementation Manager is responsible for deep discovery of client needs to configure Loop\u2019s system and project managing each implementation through post-launch hypercare to ensure internal and external timelines are met.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout the Role\n\nWe are looking for an Implementation Manager to collaborate across Sales,\nPre-Sales, Engineering and Customer Success to help provide clients with a\nseamless onboarding experience. The Implementation Manager is responsible for\ndeep discovery of client needs to configure Loop\u2019s system and project managing\neach implementation through post-launch hypercare to ensure internal and\nexternal timelines are met. The Implementation Manager partners with operations\nand engineering to ensure the configured end product accurately addresses client\nneeds and is appropriately supported by operations for ongoing servicing. The\nImplementation Manager will support client implementations both onsite and\nvirtually in order to provide product and operations expertise to configure the\nclient\u2019s instance to support their needs while suggesting best practices that\nmay require change management.\n\nKey Responsibilities\n\n * Facilitate project management for solution scoping and implementations,\n   including, but not limited to:\n    * Lead the onboarding process for new clients, ensuring a smooth transition\n      from sales to implementation. Collaborate closely with the sales team to\n      understand client needs and requirements.\n    * Leading kick-off calls - remote (sometimes on-site) sessions providing an\n      overview of Loop\u2019s solution\n    * Develop and execute comprehensive implementation plans for each client,\n      including timelines, milestones, and deliverables. Coordinating with\n      cross-functional teams to ensure all implementation aspects are completed\n      on time.\n    * Work directly with Loop\u2019s technical architect to scope use cases for\n      Loop\u2019s product & roadmap.\n    * Weekly status meetings \u2013 client calls to review progress, obstacles,\n      upcoming tasks, etc.\u00a0\n    * Identifying and consulting with clients on business process\n      transformation, optimization, and best-practice initiatives, testing,\n      training, managing go-live, hyper-care, and system cutovers\n    * Post-implementation handoff \u2013 ensure the implementation is a success,\n      before transitioning the account to our customer success team\n\n * Responsible for multiple projects at once, with varying stages of\n   implementation; must be highly organized with a strong sense of urgency to\n   meet deadlines\n * Owns functional requirements that must be clearly documented, are\n   comprehensive, and easily trackable. Must have relevant experience to lead\n   detailed discovery sessions on business and technical requirements.\n\nExperienced Required\n\n * 3-5 years of customer-facing experience in one or more of the following:\n    * Supply chain/logistics technology integrations, or\n    * Project/Account Management, in the logistics or transportation industry\u00a0\n\n * 3+ years of direct involvement in the Transportation, Logistics, Brokerage\n   and/or Supply Chain Industri ...
#             },
#             "created_at": "2024-07-13 01:29:25.335761"
#         },
#         {
#             "id": 7594539,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4721423004",
#             "data": {
#                 "title": "Customer Success Associate",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "As a Customer Success Associate at Loop, based in Chicago, you are responsible for managing the audit process, ensuring accuracy, automation, and continuous improvement to meet client's key performance indicators. This role involves working closely with Customer Success Managers, Product and Engineering teams, and provides a pathway to grow into Customer Success Manager roles.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout the Role\n\nAs a Customer Success Associate, you will be responsible for managing the audit\nprocess; ensuring accuracy, automation and continuous improvement to meet our\nclient\u2019s key performance indicators. The Customer Success Associate is directly\nresponsible for reducing overcharges, optimizing invoice management and enabling\nactionable data for our clients that is critical to their business. You will\nplay a key role in identifying opportunities and ways to improve our products to\nenhance customer experience and stickiness, working alongside Customer Success\nManagers, Product and Engineering. Individuals in this role can grow into\nCustomer Success Managers if they demonstrate aptitude and interest in that\npath. This role is located in Chicago and requires the individual to be in\noffice multiple days per week.\u00a0\n\nKey Responsibilities\n\n * Oversee and manage the day-to-day audit process for clients\n * Proactively identify changes we can make to our internal application in order\n   to improve and enable automation to the audit process\n * Partner cross functionally with Customer Success, Engineering and Product to\n   provide critical feedback on the audit process and make suggested\n   improvements\n * Analyze freight cost data; identify discrepancies and errors in carrier\n   billing; work with carriers to address systemic issues\n * Support customers through managing disputes, claims, and other exceptions\n   related to billing and payment transactions\n * Take the perspective of who we serve into everything you do, anticipating\n   client needs, and responding quickly\n * Partner with Customer Success Managers to ensure client satisfaction and\n   retention\n\nExperienced Required\n\n * Entry level experience with desire to learn new skills; previous experience\n   in operations, customer service or account management in the\n   logistics/transportation industry is nice to have\n * Ability to collect data, analyze results, and draw valid conclusions\n * Passion for technology and data\n * Obsessive attention to detail\n * Proven problem solving results\n * Excellent written & spoken communication skills\n\nBenefits & Perks\n\n * Premium Medical, Dental, and Vision Insurance plans, premiums covered 100%\n   for you\n * 401k plan\n * Unlimited PTO\n * Generous professional development budget to feed your curiosity\n * Physical and Mental fitness subsidies for yoga, meditation, gym, or ski\n   membership\n\nGreat article about freight industry and Why You Should Join Loop\n[https://whyyoushouldjoin.substack.com/i/139417454/why-you-should-join-loop]"
#             },
#             "created_at": "2024-07-13 01:29:25.580032"
#         },
#         {
#             "id": 7594540,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4796168004",
#             "data": {
#                 "title": "Software Engineer Intern, Full-Stack",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "As a full-stack engineer, you will work closely with founders and customers to understand and solve their logistics billing and payment pain points. You will help define the product and ship features that directly impact our customers.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n(https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout You\nAs a full-stack engineer, you will work closely with founders and customers to\nunderstand and solve their logistics billing and payment pain points. You will\nhelp define the product and ship features that directly impact our customers.\nYou will face and solve many complex technical challenges while you receive\nguidance and feedback from the team. You will shape the Loop DNA and define how\nwe grow as a company.\n\nResponsibilities\n\n * Work cross-functionally with product, design, and sales to understand\n   requirements and ship thoughtful solutions.\n\n * Write high-quality code optimized for extensibility.\n\n * Engage in code reviews to maintain a high bar of engineering excellence.\n\n * Lead discussions and documentation to communicate and arrive at the best\n   technical design.\n\n * Work across different components boundaries, from frontend to backend, and\n   even infrastructure layers.\n\n * Promote better practices and share technical knowledge across the team.\n\n * Help grow Loop through deliberate feedback on product, process, and culture.\n\nQualifications\n\n * Experience with TypeScript and tools such as GraphQL, Relay, React, and\n   Node.js.\n\n * Experience working at early-stage companies where you shipped products end to\n   end and wore many hats.\n\nUnder the Hood\n\n * Infrastructure: AWS, CDK, Fargate ECS\n\n * Backend: TypeScript, Node.js, Prisma, NestJS, PostgreSQL, Redis,\n   Elasticsearch, GraphQL\n\n * Frontend: TypeScript, React, Relay, Ant Design, Vite, GraphQL\n\nWhy you should join Loop? - https://whyyoushouldjoin.substack.com/p/loop"
#             },
#             "created_at": "2024-07-13 01:29:25.686746"
#         },
#         {
#             "id": 7594541,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4102236004",
#             "data": {
#                 "title": "Software Engineer, Full-Stack",
#                 "remote": false,
#                 "salary": "120k - 190k",
#                 "company": "Loop",
#                 "summary": "As a full-stack engineer at Loop, you will work closely with founders and customers to understand and solve their logistics billing and payment pain points, shaping the company's technical and cultural development.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n(https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout You\nAs a full-stack engineer, you will work closely with founders and customers to\nunderstand and solve their logistics billing and payment pain points. You will\nhelp define the product and ship features that directly impact our customers.\nYou will face and solve many complex technical challenges while you receive\nguidance and feedback from the team. You will shape the Loop DNA and define how\nwe grow as a company.\n\nResponsibilities\n\n * Work cross-functionally with product, design, and sales to understand\n   requirements and ship thoughtful solutions.\n\n * Write high-quality code optimized for extensibility.\n\n * Engage in code reviews to maintain a high bar of engineering excellence.\n\n * Lead discussions and documentation to communicate and arrive at the best\n   technical design.\n\n * Work across different components boundaries, from frontend to backend, and\n   even infrastructure layers.\n\n * Promote better practices and share technical knowledge across the team.\n\n * Help grow Loop through deliberate feedback on product, process, and culture.\n\nQualifications\n\n * Five years of software engineering experience.\n\n * Experience with TypeScript and tools such as GraphQL, Relay, React, and\n   Node.js.\n\n * Experience working at early-stage companies where you shipped products end to\n   end and wore many hats.\n\nUnder the Hood\n\n * Infrastructure: AWS, CDK, Fargate ECS\n\n * Backend: TypeScript, Node.js, Prisma, NestJS, PostgreSQL, Redis,\n   Elasticsearch, GraphQL\n\n * Frontend: TypeScript, React, Relay, Ant Design, Vite, GraphQL\n\nCompensation\n\n * Base pay 120k - 190k\n\nBenefits & Perks\n\n * Premium Medical, Dental, and Vision Insurance plans\n\n * Insurance premiums covered 100% for you\n\n * Unlimited PTO\n\n * Fireside chats with industry leading keynote speakers\n\n * Off-sites in locales such as Napa and Tahoe\n\n * Generous professional development budget to feed your curiosity\n\n * Physical and Mental fitness subsidies for yoga, meditation, gym, or ski\n   memberships\n\nWhy you should join Loop? - https://whyyoushouldjoin.substack.com/p/loop"
#             },
#             "created_at": "2024-07-13 01:29:26.144063"
#         },
#         {
#             "id": 7594542,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/5227050004",
#             "data": {
#                 "title": "Software Engineer",
#                 "remote": true,
#                 "salary": "$150,000 to $170,000 per year",
#                 "company": "Loop",
#                 "summary": "Build new and scale up Loop products. Work and effectively communicate in a dynamic and fast-moving environment across engineering, product, risk, growth and go-to-market to develop product and system specifications, metrics, KPIs and support procedures.",
#                 "job_description": "Job duties \u2013 Build new and scale up Loop products. Design and contribute new\nfeatures to Loop Platforms:\u00a0Freight Audit, Data Ingestion, Payments.\nContinuously increase ownership and deepen expertise in both\u00a0product and\nplatform areas. Inspire and mentor young engineers and interns. Work and\neffectively\u00a0communicate in a dynamic and fast-moving environment across\nengineering, product, risk, growth and go-to-\u00a0market to develop product and\nsystem specifications, metrics, KPIs and support procedures. Contribute\nto\u00a0roadmap and plans, help define and meet team\u2019s goals. Work with product and\nbusiness teams to incorporate\u00a0customer feedback to constantly improve product.\nContinuously improve engineering processes, tools, and\u00a0systems that allow us to\nscale the code base, productivity, and the team. Proactively engage with peers\nand\u00a0managers to provide and solicit feedback, recruit, interview engineering\ncandidates and develop interview\u00a0questions, and foster the culture of\nexcellence, velocity and humility. Ability to work from home (WFH) a few\u00a0days a\nweek.\n\nEducation and Experience required\u00a0\u2013 Bachelor\u2019s degree in Computer Science,\nBusiness Administration and\u00a0Computer Science, or a related technical field and 3\nyears of experience in software engineering.\u00a0\n\nBackground \u2013 3 years of experience contributing to software systems by\ndesigning, developing, testing,\u00a0maintaining, and improving software. 3 years of\nexperience using full stack technologies, including React,\u00a0NodeJS, GraphQL, and\nPostgreSQL, and frameworks (NestJs, Spring, and Rails). 3 years of experience\nbuilding\u00a0and maintaining production environments with AWS ECR, ECS, EC2, and\nensuring system stability using\u00a0observability tools including Datadog or\nGraphite. 3 years of experience working cross functionally with\ndesigners, product managers and business stakeholders to align on project goals\nand delivery projects in a\u00a0timely manner, and leverage analytics tools including\nSnowflake and Mode to track deliverable metrics. 3\u00a0years of experience scoping,\nplanning, and executing on software projects spanning multiple months\nand\u00a0involving multiple engineers. 3 years of experience using project tracking\nsoftware including Jira or Linear to\u00a0ensure projects are scoped and delivered on\ntime. 1 year of experience mentoring junior engineers and\u00a0providing guidance and\nsupport when necessary. 1 year of experience setting coding standards and\nbest\u00a0practices for team members.\n\nLocation \u2013 San Francisco, CA (Ability to WFH a few days/week)\n\n\nRate of pay \u2013 $150,000 to $170,000 per year\n\n\nHow to apply \u2013 By email to career-intakes@loop.com with (#LPSE) in the subject\nline."
#             },
#             "created_at": "2024-07-13 01:29:26.191639"
#         },
#         {
#             "id": 7594543,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/5011936004",
#             "data": {
#                 "title": "Technical Consultant/Architect",
#                 "remote": false,
#                 "salary": "$160 - 180K salary commensurate with experience, plus equity",
#                 "company": "Loop",
#                 "summary": "As a Technical Architect within the Customer Success function, you will support our clients in navigating the complexities of integrations, API interactions, and data exchanges as they transform digitally with Loop. You'll be a critical Customer Success onboarding team member with a strong technical background and expertise in development, solution architecture, and integrations.",
#                 "job_description": "About Loop\n\nLoop's mission is to simplify logistics payments. Loop is building modern\neconomic infrastructure to enable frictionless payments for one of the world's\nlargest industries \u2013 logistics. Shippers, carriers and 3pls that onboard to Loop\neliminate painful billing and payment errors \u2013 resulting in spending 4% less and\nan 80% increase in back office productivity. Loop's new logistics payment\nplatform won\u2019t just change how people pay. It\u2019s going to fundamentally move\nlogistics forward.\n\nLoop has a product-obsessed team that enjoys building core infrastructure that\nimpacts everyone. Investors include Founders Fund, 8VC, Susa Ventures, Flexport,\nand 50 industry leading angel investors. The team is made up of talented\nindividuals from technology companies like Uber, Google, Flexport, Meta, Intuit\nand Rakuten \u2013 as well as traditional logistics companies like CH Robinson.\n\nAbout the Role\n\nAs a Technical Architect within the Customer Success function, you will support\nour clients in navigating the complexities of integrations, API interactions,\nand data exchanges as they transform digitally with Loop. You'll be a critical\nCustomer Success onboarding team member with a strong technical background and\nexpertise in development, solution architecture, and integrations.\n\nKey Responsibilities\n\n * Facilitate technical onboarding, development, and execution, including, but\n   not limited to:\n    * Coordinate activities with internal stakeholders to develop integration\n      solutions and fill product gaps between a wide range of commercial and\n      legacy client systems\n    * Technical deep dive \u2013 familiarity with TMS/FPA/WMS/YMS/ERP systems common\n      in the freight industry\n    * Lead integrations between Loop and the client\u2019s other external software\n      systems (TMS/ERP/BI Tools)\u00a0\n    * Develop custom solutions outside of Loop to support client requirements\n      when required\n    * Identify product gaps and document requirements to be shared with internal\n      teams\n    * Weekly status meetings \u2013 weekly calls with clients to review progress,\n      obstacles, upcoming tasks, etc.\u00a0\n    * Identifying and consulting with clients on business process\n      transformation, optimization and best-practice initiatives, testing,\n      training, managing go-live and system cutovers\n    * Post-Onboarding Success management and planning\n\n * Responsible for multiple projects at once, with varying stages of\n   implementation; must be highly organized with a strong sense of urgency to\n   meet deadlines\n * Owns technical requirements & joint milestones to drive time to value\u00a0\n * Identify bottlenecks in the onboarding process and work to improve via\n   product and process\n\nExperienced Required\n\n * Experience (3 - 5 years) in development, consulting, professional services,\n   or customer engineering.\n * Experience building clients though complex integrations and technical\n   transformations\n * Proficiency in at least one object-oriented programming language, such as\n   Java, JavaScript, Node.js, Python, and TypeScript.\n * Hands-on expertise in data transfer, integrations, and API utilization\n * Ability to create custom solutions to integrate with APIs using IPaaS tools\n   or other tools\n * Exceptional written and verbal communication skills can dive deep into\n   technical discussions\n * Translate concepts for business users identifying end-to-end requirements\n * Strong presentation skills for effectively communicating both\n   business-oriented solutions and advanced technical concepts.\n * Track record of leading and executing technical projects, inspiring change\n   across various levels of IT executives and organizations.\n * Past collaboration with Sales, Success teams, Consultants, and System\n   Integrators.\n * Ability to travel up to 20%\n * This is a hybrid role based in Chicago\u0 ...
#             },
#             "created_at": "2024-07-13 01:29:26.340356"
#         },
#         {
#             "id": 7594544,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4866545004",
#             "data": {
#                 "title": "Brand Designer",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "Loop is looking for a Brand designer to join the Design team and evolve our brand identity to new heights. As a Brand Designer, you will give shape to the ways Loop shows up and interacts with the world through various touch-points, including client communications, marketing efforts, and events.",
#                 "job_description": "Loop is growing our brand identity that will interact with millions in our\npursuit to become the world's largest logistics payment network. We're looking\nfor a Brand designer to join the Design team and evolve our brand identity to\nnew heights. As a Brand Designer, you will give shape to the ways Loop shows up\nand interacts with the world through various touch-points, including client\ncommunications, marketing efforts, and events.\n\nThis is a highly collaborative role where you will partner closely with Sales,\nMarketing, and Product, with room to initiate projects that build awareness of\nthe Loop brand and product benefits in engaging and novel ways. You will play an\nessential role in evolving the Loop brand and building corporate culture. You're\na strong communicator and creates assets with a critical eye to the level of\ndetail, polish, craft, and consistency in our overall output. The ideal\ncandidate for this role is self-motivated, medium-agnostic, and loves a creative\nchallenge.\n\nWhat you'll do at Loop:\n\n * See projects throughout the entire design process; from creative conception\n   to production\n * Craft engaging visuals and digital experiences in a fast-paced environment\n * Collaborate with\u00a0product design, and growth\u00a0teams to concept\u00a0campaigns,\n   client communications, and feature launch announcements\n * Design for a wide range of projects while ensure consistency of the\u00a0Loop\n   brand across\u00a0many surfaces including our\u00a0website and events\n\nWe'd love to hear from you if you have:\n\n * Experience in fintech, enterprise b2b, or logistics\n * Excellence in typography, color, layout, and composition\n * A strong portfolio showcasing brand experience across a range of mediums\n * Embrace an iterative design process and receptive to feedback\n * Able to work independently, drive multiple projects at a time, and iterate\n   quickly\n * Foster strong working relationships with team members and cross-functional\n   partners\n * Comfortable in your soft skills: listening, negotiating, and decision-making\n\n\u00a0\n\nAbout Loop:\n\nLoop is on a mission to unlock profits trapped in the supply chain\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nusechatgpt init success\nusechatgpt init success\nusechatgpt init success"
#             },
#             "created_at": "2024-07-13 01:30:05.104946"
#         },
#         {
#             "id": 7594545,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4126037004",
#             "data": {
#                 "title": "Senior Product Designer",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "We're looking for a Senior Product Designer that appreciates the massive opportunity that human-centered design poses for the supply chain industry to join Loop's core product team. If you get energy from creating elegant visual shorthand, building workflows that feel like magic, and developing adaptable systems, this might be the opportunity of a lifetime.",
#                 "job_description": "About Loop\n\nLoop is on a mission to unlock profits trapped in the supply chain\n(https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)\n[https://loop.com/article/unlock-profit-trapped-in-your-supply-chain)] and lower\ncosts for consumers. Bad data and inefficient workflows create friction that\nlimits working capital and raises costs for every supply chain stakeholder.\n\nLoop\u2019s modern audit and pay platform uses our domain-driven AI to harness the\ncomplexity of supply chain data and documentation. We improve transportation\nspend visibility so companies can control their costs and power profit. That is\nwhy industry leaders like J.P. Morgan Chase, Great Dane, Emerge, and Loadsmart\nwork with Loop.\n\nOur investors include J.P. Morgan, Index Ventures, Founders Fund, 8VC, Susa\nVentures, Flexport, and 50 industry-leading angel investors. Our team brings\nsubject matter expertise from companies like Uber, Google, Flexport, Meta,\nSamsara, Intuit, Rakuten, and long-standing industry leaders like C.H. Robinson.\n\nAbout the job\n\nWe're looking for a Senior Product Designer that appreciates the massive\nopportunity that human-centered design poses for the supply chain industry to\njoin Loop's core product team. If you get energy from creating elegant visual\nshorthand, building workflows that feel like magic, and developing adaptable\nsystems, this might be the opportunity of a lifetime.\u00a0\n\nWhat you\u2019ll do\n\n * Product strategy -\u00a0 Contribute to our digital transformation strategy through\n   design\n\n * Prototyping - Iterate and visualize concepts at every level of fidelity.\n   Figma nerds welcome.\n\n * Decomposition - Create simple, intuitive building blocks that solve complex\n   webs of problems\n\n * UI/Visual design - Lay the groundwork for beautiful interfaces and\n   interaction metaphors\u00a0\n\nYou will have great autonomy over your work, so a wide skill set is necessary.\nHowever, you could also be passionate in growing or flexing in one area. You\nmight be the kind of designer who prototypes every micro-interaction, or the\nkind who loves data visualization. If you\u2019re excited about this role but your\npast experience doesn\u2019t align perfectly with the points outlined in the job\ndescription, we still encourage you to apply. You may be just the right\ncandidate for this or other roles.\n\nBenefits & Perks\n\n * Premium Medical, Dental, and Vision Insurance plans\n\n * Insurance premiums covered 100% for you\n\n * Unlimited PTO\n\n * Fireside chats with industry leading keynote speakers\n\n * Offsites in locales such as Napa and Tahoe\n\n * Generous professional development budget to feed your curiosity\n\n * Physical and Mental fitness subsidies for yoga, meditation, gym, or ski\n   memberships\n\nWhy You Should Join Loop\n[https://whyyoushouldjoin.substack.com/i/139417454/why-you-should-join-loop]"
#             },
#             "created_at": "2024-07-13 01:30:05.234362"
#         },
#         {
#             "id": 7594546,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/5227051004",
#             "data": {
#                 "title": "Product Designer",
#                 "remote": false,
#                 "salary": "$115,000 to $140,000 per year",
#                 "company": "Loop",
#                 "summary": "The Product Designer will contribute to digital transformation strategy, create UI components, and perform user research to inform product strategy. The role involves prototyping, visual design, and problem-solving in collaboration with engineers and product managers.",
#                 "job_description": "Job title \u2013 Product Designer\n\n\nJob duties \u2013 Product strategy - Contribute to our digital transformation\nstrategy through design. Prototyping -\u00a0Iterate and visualize concepts at every\nlevel of fidelity. Problem decomposition - Break down complex\u00a0processes and\nlarge amounts of feedback into simple problems. Contribute to design system -\nCreate simple,\u00a0intuitive UI components that handle large varieties of use cases.\nUI/Visual design - Lay the groundwork for\u00a0beautiful interfaces and interaction\nmetaphors. User research - Utilize various research methods to uncover\u00a0pain\npoints and needs that inform product strategy.\n\n\u00a0\n\nEducation and Experience required \u2013 Bachelor\u2019s degree in Product Design,\nHuman-Computer Interaction (HCI), or a related field and 1 year of experience in\nproduct design.\n\n\nBackground \u2013 Demonstrated ability in identifying key user pain points and\nimproving interfaces based on quantitative or qualitative data analysis,\nevidenced by project documentation over the course of at least one year showing\nmeasurable improvement in user feedback due to the candidate&#39;s\ncontributions. 1 year of experience with Figma for creating interaction design\nassets, including process diagrams, low-fidelity mockups, and high-fidelity\nprototypes. Demonstrated proficiency in all phases of the innovative design\nprocess, with at\u00a0least 1 year of experience problem solving in an enterprise\nenvironment. 1 year of experience collaborating with software engineers and\nproduct managers with at least 2 successfully implemented projects that involved\ncomplex data handling. Demonstrated ability to lead design thinking sessions\nwith software engineers and product managers, as evidenced by at least 1 year of\nexperience collaborating on solutions that span across mobile and web\ninterfaces. 1 year of experience analyzing operational processes and service\ndesign, focusing on improving software interfaces as well as human factors. 1\nyear of experience working with software engineers to test and implement user\ninterfaces that involve complex information architectures. Strong understanding\nof UI design principles, as evidenced by at least 1 year of professional design\nexperience focusing on layout, typography, color theory, and visual hierarchy.\nProficiency in effective questioning techniques to gather meaningful data,\nevidenced by at least 1 year of experience leveraging and executing at least 3\ndistinct research methods. 1 year of experience in strategic thinking and\ncompetitive analysis with a proven track record of applying research insights to\ndesign products.\n\nLocation \u2013 San Francisco, CA\n\nRate of pay \u2013 $115,000 to $140,000 per year\n\nHow to apply \u2013 By email to career-intakes@loop.com with #LPPD in the subject\nline.\n\n\u00a0"
#             },
#             "created_at": "2024-07-13 01:30:05.499444"
#         },
#         {
#             "id": 7594548,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://loop.com/",
#             "url": "https://boards.greenhouse.io/loop/jobs/4138181004",
#             "data": {
#                 "title": "Customer Success Manager",
#                 "remote": false,
#                 "company": "Loop",
#                 "summary": "Each and every challenge the Customer Success team works to ensure that our clients are maximizing the value they are receiving from Loop.",
# ...
#             },
#             "created_at": "2024-07-13 01:32:00.017526"
#         },
#         {
#             "id": 7594556,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://www.merge.dev/",
#             "url": "https://boards.greenhouse.io/merge/jobs/5166707004",
#             "data": {
#                 "title": "Senior Manager, Revenue Marketing",
#                 "remote": false,
#                 "salary": "Ramp up our account-based marketing: Support our sales outbound motion to target accounts with campaigns that capture the interest of our buyers.",
#                 "company": "Merge API",
#                 "summary": "Merge is hiring a Senior Manager, Revenue Marketing to help generate predictable self-serve and sales pipeline growth by designing and executing marketing campaigns targeted at developers and product leaders in startups. This role includes developing integrations with dozens of vendors, aligning with various team areas, and optimizing marketing efforts.",
#                 "job_description": "At Merge, we revolutionize the way B2B companies integrate. Unfamiliar with the\nintegration problem? The average company expects to spend hundreds of hours a\nyear integrating with dozens or more vendors. Alignment between sales,\npartnerships, product management, design, engineering, and customer success (a\nlot, right?) is absolutely critical \u2014 and a major headache. Integrations are a\nto-do that goes on and on.\n\nOur Unified API empowers developers to offer integrations with hundreds of\nplatforms instantly. Now we\u2019re hiring for you: an ambitious leader ready to help\nbuild, design, and support enterprise-grade software scaled to millions of\nusers.\n\nWhat you will do:\n\n * Ramp up our account-based marketing: Support our sales outbound motion to\n   target accounts with campaigns that capture the interest of our buyers.\n * Be an audience expert: Build a strong intuition of our audience of developers\n   and product leaders in startups responsible for building product\n   integrations.\n * Dream up campaigns: You\u2019ll ideate and create new campaigns in collaboration\n   with Product Marketing, Website/Ops, and Design team members.\n * Then execute those campaigns: Manage and continuously optimize day-to-day\n   email campaigns to target our key developer and product personas.\n * Create sustainable pipeline: Scale our marketing efforts to generate\n   predictable self-serve (signups, PQLs) and sales pipeline (demos,\n   opportunities).\n\nThe ideal candidate will have:\n\n * Marketing professional: 5+ years demand generation experience, preferably for\n   B2B SaaS companies that have self-serve or product-led growth models.\n * Thrive in a fast-paced environment: You\u2019re hungry for rapid growth and\n   pioneering a new market in opposition to existing competition.\n * Analytical and experimental: Use analytical insights to continuously test\n   campaigns, subject lines, and calls to action. You\u2019ll ensure maximum value is\n   created from our investments.\u00a0\n * Cogent communicator: You\u2019re an excellent listener, presenter, and problem\n   solver with a hands-on approach to writing emails and writing landing page\n   copy.\n * Knows marketing tools: You\u2019re comfortable with the full marketing stack to\n   collect, enrich and report on our funnel. You\u2019re excited to put Salesforce,\n   Hubspot, Google Analytics, and more to use!\n * Intuition for channels: Extensive experience with segmenting audiences and\n   developing integrated lifecycle campaigns. Ability to drive our partners and\n   vendors to deploy best practices and achieve results.\n\nCompensation\n * The cash compensation range for this role is $150,000 - $180,000.\n * Actual compensation packages are based on a wide array of factors unique to\n   each candidate, including but not limited to skill set, years & depth of\n   experience, and certifications. In addition to cash compensation, all full\n   time employees receive an equity compensation package.\n\nBenefits\n * Unlimited PTO + 10 company holidays\n * Pre-Tax commuter benefits\n * 100% covered health, vision, and dental insurance\u00a0\n * 401K Plan\n * $200 one-time home office stipend\n * In office snacks and free dinner when working past 7pm\n\nMerge is an equal opportunity employer, and we value diversity at our company.\nWe do not discriminate on the basis of race, religion, color, national origin,\ngender, sexual orientation, age, marital status, veteran status, disability\nstatus, or any other protected class."
#             },
#             "created_at": "2024-07-13 01:32:00.235364"
#         },
#         {
#             "id": 7594557,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://www.merge.dev/",
#             "url": "https://boards.greenhouse.io/merge/jobs/4069293004",
#             "data": {
#                 "title": "Account Executive",
#                 "remote": false,
#                 "salary": "$180,000 - $260,000",
#                 "company": "Merge API",
#                 "summary": "Merge is looking for an account executive to help lay the foundations for repeatable and consistent revenue growth. This role involves building customer-centric sales processes, full sales-cycle management from prospecting to closing, and collaborating with multiple teams to improve the company's offerings.",
#                 "job_description": "At Merge, we revolutionize the way B2B companies integrate. Unfamiliar with the\nintegration problem? The average company expects to spend hundreds of hours a\nyear integrating with dozens or more vendors. Alignment between sales,\npartnerships, product management, design, engineering, and customer success (a\nlot, right?) is absolutely critical \u2014 and a major headache. Integrations are a\nto-do that goes on and on.\n\nOur Unified API empowers developers to offer integrations with hundreds of\nplatforms instantly. Now we\u2019re hiring for you: an ambitious leader ready to help\nbuild, design, and support enterprise-grade software scaled to millions of\nusers.\n\nMerge is looking for an account executive to help lay the foundations for\nrepeatable and consistent revenue growth. You should be driven, adaptable to\nchange and creative as you help us test out new ideas and find what works in the\npursuit of building a truly customer-centric sales process. This is a fantastic\nopportunity to play a key role in an organization that cares deeply about\ndelivering an exceptional customer experience with a in-demand product that\nalready has proven product-market fit.\n\nWhat You Will Do:\n * Help organizations of all sizes achieve immense growth by executing on their\n   integration strategies\n * Run full sales cycles from prospecting to closing, as well as working\n   opportunities generated by marketing and SDRs\n * Cultivate strong customer relationships and position yourself as a trusted\n   advisor to facilitate expansions, renewals and referrals across your\n   customers\n * Build and redesign sales processes to help us create an exceptional customer\n   journey\n * Lead by example as a mentor for new sales team members as we continue to grow\n * Collaborate with marketing, engineering, product, growth and platform teams\n   to share your customer insights and help us continually improve all areas of\n   Merge\u2019s offering\n * Experiment with new ideas, processes and tools that will improve and scale\n   our sales motion\n\nThe ideal candidate will have:\u00a0\n * 2-5+ years of experience as a top-performing account executive\n * Consistent track record of exceeding your quota\n * Experience selling a technical SaaS product with an ACV of $50k+\n * Ability to create repeatable sales processes across a wide range of customer\n   interactions and customer sizes\n * Deep customer empathy and unrivaled communication skills\n * Full sales-cycle management skills, from prospecting to closing\n * Self-motivated and comfortable in a fast-paced and rapidly changing\n   environment\n * Prior experience as an early employee at a startup and/or selling an API\n   product or developer tool are a bonus\n\nCompensation\n\n * The cash compensation range for this role is $180,000 - $260,000.\n * Actual compensation packages are based on a wide array of factors unique to\n   each candidate, including but not limited to skill set, years & depth of\n   experience, and certifications. In addition to cash compensation, all full\n   time employees receive an equity compensation package\n\nBenefits\n\n * Unlimited PTO + 10 company holidays\n * Pre-Tax commuter benefits\n * 100% covered health, vision, and dental insurance\u00a0\n * 401K Plan\n * $200 one-time home office stipend\n * In office snacks and free dinner when working past 7pm\n\nMerge is an equal opportunity employer, and we value diversity at our company.\nWe do not discriminate on the basis of race, religion, color, national origin,\ngender, sexual orientation, age, marital status, veteran status, disability\nstatus, or any other protected class."
#             },
#             "created_at": "2024-07-13 01:32:00.530665"
#         },
#         {
#             "id": 7594558,
#             "pipeline": 1017,
#             "run": 1553,
#             "seed": "https://www.merge.dev/",
#             "url": "https://boards.greenhouse.io/merge/jobs/5132760004",
#             "data": {
#                 "title": "Software Engineer, Data Platform",
#                 "remote": false,
#                 "salary": "$170,000 - $190,000",
#                 "company": "Merge API",
#                 "summary": "The SOFTWARE ENGINEER, DATA PLATFORM role at Merge API involves building, designing, and supporting enterprise-grade software that empowers developers to offer integrations with hundreds of platforms. This position entails significant responsibility for data quality and efficiency, appealing to those with strong technical coding skills and an interest in scalability and big data challenges.",
#                 "job_description": "At Merge, we revolutionize the way B2B companies integrate. Unfamiliar with the\nintegration problem? The average company expects to spend hundreds of hours a\nyear integrating with dozens or more vendors. Alignment between sales,\npartnerships, product management, design, engineering, and customer success (a\nlot, right?) is absolutely critical \u2014 and a major headache. Integrations are a\nto-do that goes on and on.\n\nOur Unified API empowers developers to offer integrations with hundreds of\nplatforms instantly. Now we\u2019re hiring for you: an ambitious leader ready to help\nbuild, design, and support enterprise-grade software scaled to millions of\nusers.\n\nThis high impact role will sit within our platform team, being an essential\ncontributor to Merge's platform and data strategy going forward. You will play a\ncrucial part in our mission of powering integrations for all B2B companies,\nhaving high ownership over data quality and data efficiency on the team. This\nrole would appeal to someone with strong technical coding skills, but who has a\ndesire to spend significant time focusing on advocating for scalability and\ndriving direction on big data challenges, combined with data and application\nengineering.\n\nWhat you will do:\n\n * You will be responsible for building and maintaining high quality, highly\n   efficient integrations that sync data extremely effectively\n * Provide support for the platform team as a whole, being the data quality\n   expert on a team of 6-8\n * Lead initiatives for enhancing and optimizing our our internal tooling, while\n   defining key metrics to power and measure the efficacy of our integrations.\n * Use data to solve business problems, unblock hurdles within the platform\n   team, and deliver high quality results\n * Work cross-functionally with engineering, post-sales, product, and\n   partnerships teams to deliver enterprise-grade integrations & expand Merge's\n   coverage across 7 categories\n * Driving ETL and data performance initiatives for the team\n * Mentor junior talent on the team\n\nThe ideal candidate will have:\n\n * 5+ years in engineering roles with startup experience being a plus\n * Prior experience working with APIs and integrations\n * Technical understanding and problem solving abilities, through the lens of a\n   data heavy technical role\n * Experience with ETL and large data processing and movement\n * Strong stakeholder management skills, with an ability to work\n   cross-functionally both with technical and non-technical teams to drive\n   companywide outcomes, especially in ambiguous situations\n\nCompensation\n * The cash compensation range for this role is\u00a0$170,000 - $190,000.\n * Actual compensation packages are based on a wide array of factors unique to\n   each candidate, including but not limited to skill set, years & depth of\n   experience, and certifications. In addition to cash compensation, all full\n   time employees receive an equity compensation package.\n\nBenefits\n * Unlimited PTO + 10 company holidays\n * Pre-Tax commuter benefits\n * 100% covered health, vision, and dental insurance\u00a0\n * 401K Plan\n * $200 one-time home office stipend\n * In office snacks and free dinner when working past 7pm\n\nMerge is an equal opportunity employer, and we value diversity at our company.\nWe do not discriminate on the basis of race, religion, color, national origin,\ngender, sexual orientation, age, marital status, veteran status, disability\nstatus, or any other protected class."
#             },
#             "created_at": "2024-07-13 01:32:05.838592"
#         }
#     ],
#     "errors": []
# }

# %% [markdown]
# # Ecommerce Price API Example
# This pipeline shows how to use Indexical to scrape ecommerce prices. This will pull the `product_name`, `image_link`, `product_details_page`, and `price` for each product on a product listing page.

# %% [markdown]
# ### Setup
# In this section, we'll set up the environment to start using Indexical's API by importing the necessary libraries and saving the API key. Start by inputting your API key below. You can generate an API key from the Indexical console by selecting `Keys` and then hitting `New API Key`.

# %%
import requests
import json

# %%
API_KEY="<REPLACE WITH YOUR API_KEY>"

# %% [markdown]
# ### Add Pipeline
# To create scalable data extraction workflows, Indexical allows you to construct a pipeline of high-level steps that describe how to go from a URL / query to clean, structured data. Each step contains an `action` that is tied to a task-specific agent on our end, as well as a natural language `goal` to instruct the agent. We'll start by importing the `ecommerce_price.json` file as our pipeline and printing it below.

# %%
file_path="pipelines/ecommerce_price.json"
with open(file_path, 'r') as file:
    pipeline_steps = json.load(file)
    print(json.dumps(pipeline_steps, indent=4))
# Out:
# {
#     "name": "ecommerce_price",
#     "steps": [
#         {
#             "action": "extract-many",
#             "goal": "extract the listed information about each product listing",
#             "schema": {
#                 "product_name": {
#                     "type": "string",
#                     "description": "the name of the product"
#                 },
#                 "product_price": {
#                     "type": "string",
#                     "description": "the price (discounted if available) of the product"
#                 },
#                 "image_link": {
#                     "type": "string",
#                     "description": "the link to the product image, if available"
#                 },
#                 "product_listing_link": {
#                     "type": "string",
#                     "descripiton": "the link to the product listing details page"
#                 }
#             }
#         }
#     ]
# }

# %% [markdown]
# Now, we'll call Indexical's `pipelines` API endpoint to save that pipeline for use in future data extraction workflows Each API request requires the header with `x-api-key`, and you include the JSON pipeline as the API body.

# %%
response = requests.post("https://app.indexical.dev/pipelines",
                          headers={'x-api-key': API_KEY}, 
                          json=pipeline_steps)

if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
else:
    print(response.status_code)

# %% [markdown]
# ### Run data extraction job
# Once you've saved your pipeline, you can then run that workflow on any set ofwebsites / queries through that pipeline. Indexical will use AI to handle the process of mapping that pipeline to relevant selectors and information on each page, gathering and transforming the website into a clean, standardized schema of your choosing.
#
# In this case, I will run the `ecommerce_price` pipeline and extract all of the product information from the following [url](https://www.denydesigns.com/collections/bench).

# %%
response = requests.post("https://app.indexical.dev/runs",
                          headers={'x-api-key': API_KEY}, 
                          json={
                              "name" : "ecommerce_price", 
                              "urls" : ["https://www.denydesigns.com/collections/bench"],
                              "proxiesEnabled" : True 
                          })

# %% [markdown]
# By default, the `runs` endpoint will run the data extraction pipeline and return the results asynchronously (either available for download on the developer console or transmitted to a subscriber URL via webhooks). As a response, the `runs` endpoint will return both the `pipelineID` and `runID`.

# %%
if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
    run_id = data['id']
    print(data)
else:
    print(response.status_code)
# Out:
# {'pipeline': 514, 'id': 1546}

# %% [markdown]
# ### Getting Results
# To get the results programmatically, you can either use [webhooks](https://docs.indexical.dev/runs) or use the `outputs` endpoint. Simply call `https://app.indexical.dev/runs/:runId/outputs` with the `runID` returned by the `runs` endpoint.

# %%
output_endpoint = "https://app.indexical.dev/runs/" + str(run_id) + "/outputs"
response = requests.get(output_endpoint,
                          headers={'x-api-key': API_KEY})

# %% [markdown]
# By default, the results will be a JSON file with 2 keys `results` and `errors`. Each key will contain an array of results. Each result has a `seed` query/URL, the final `url` from which Indexical extracted the information, as well as a `data` key which has all of the data specified in the pipeline. If Indexical was not able to find information on the page that maps to a specific element, it will either return `NULL` or not output that key.

# %%
if response.status_code == 200: 
    # Convert the response to JSON format
    data = response.json()
    print(json.dumps(data, indent=4))
else:
    print(response.status_code)
# Out:
# {
#     "results": [
#         {
#             "id": 7594431,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-chinoiserie-garden-bench-whitebg-gold_large.jpg?v=1720707940",
#                 "product_name": "Britt Mills Design Chinoiserie Garden Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-chinoiserie-garden-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594432,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-banana-leaves-pink-bench-whitebg-gold_large.jpg?v=1720678245",
#                 "product_name": "Britt Mills Design Banana Leaves Pink Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-banana-leaves-pink-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594433,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-popping-peonies-beige-bench-whitebg-gold_large.jpg?v=1720678023",
#                 "product_name": "Britt Mills Design Popping Peonies Beige Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-popping-peonies-beige-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594434,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-coastal-chinoiserie-ii-bench-whitebg-gold_large.jpg?v=1720678008",
#                 "product_name": "Britt Mills Design Coastal Chinoiserie II Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-coastal-chinoiserie-ii-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594435,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-island-dreams-bench-whitebg-gold_large.jpg?v=1720677963",
#                 "product_name": "Britt Mills Design Island Dreams Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-island-dreams-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594436,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-chinoiserie-lemons-bench-whitebg-gold_large.jpg?v=1720677809",
#                 "product_name": "Britt Mills Design Chinoiserie Lemons Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-chinoiserie-lemons-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594437,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/britt-mills-design-southern-living-chinoiserie-bench-whitebg-gold_large.jpg?v=1720677759",
#                 "product_name": "Britt Mills Design Southern Living Chinoiserie Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/britt-mills-design-southern-living-chinoiserie-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594438,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-pink-flamingoes-tropical-palm-bench-whitebg-gold_large.jpg?v=1720621057",
#                 "product_name": "ChrissyInk Pink flamingoes tropical palm Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-pink-flamingoes-tropical-palm-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594439,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/emanuela-carratoni-summer-flowers-on-blue-bench-whitebg-gold_large.jpg?v=1720602509",
#                 "product_name": "Emanuela Carratoni Summer Flowers on Blue Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/emanuela-carratoni-summer-flowers-on-blue-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594440,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-chinoiserie-birds-peacock-bench-whitebg-gold_large.jpg?v=1720580981",
#                 "product_name": "ChrissyInk Chinoiserie birds peacock Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-chinoiserie-birds-peacock-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594441,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/ninola-design-color-joy-abstract-colorful-bench-whitebg-gold_large.jpg?v=1720580886",
#                 "product_name": "Ninola Design Color Joy Abstract Colorful Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/ninola-design-color-joy-abstract-colorful-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594442,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-70s-mod-fabric-repeat-orange-bench-whitebg-gold_large.jpg?v=1720372932",
#                 "product_name": "ChrissyInk 70s mod fabric repeat orange Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-70s-mod-fabric-repeat-orange-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594443,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-70s-pastel-floral-on-pink-bench-whitebg-gold_large.jpg?v=1720372782",
#                 "product_name": "ChrissyInk 70s Pastel Floral on pink Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-70s-pastel-floral-on-pink-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594444,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/the-whiskey-ginger-sequoia-national-park-california-pattern-bench-whitebg-gold_large.jpg?v=1720138725",
#                 "product_name": "The Whiskey Ginger Sequoia National Park California Pattern Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/the-whiskey-ginger-sequoia-national-park-california-pattern-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594445,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/ninola-design-polka-dots-happy-blue-bench-whitebg-gold_large.jpg?v=1720030368",
#                 "product_name": "Ninola Design Polka Dots Happy Blue Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/ninola-design-polka-dots-happy-blue-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594446,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-palm-life-tropical-palm-leaves-bench-whitebg-gold_large.jpg?v=1719965396",
#                 "product_name": "ChrissyInk Palm Life tropical palm leaves Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-palm-life-tropical-palm-leaves-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594447,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/chrissyink-california-poppies-spring-bench-whitebg-gold_large.jpg?v=1719965079",
#                 "product_name": "ChrissyInk California poppies spring Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/chrissyink-california-poppies-spring-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594448,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/design-dannick-colorful-orchid-bench-whitebg-gold_large.jpg?v=1719950478",
#                 "product_name": "DESIGN dannick colorful orchid Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/design-dannick-colorful-orchid-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594449,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/mieken-petra-designs-boho-summer-vibes-bench-whitebg-gold_large.jpg?v=1719942769",
#                 "product_name": "Mieken Petra Designs Boho Summer Vibes Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/mieken-petra-designs-boho-summer-vibes-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         },
#         {
#             "id": 7594450,
#             "pipeline": 514,
#             "run": 1546,
#             "seed": "https://www.denydesigns.com/collections/bench",
#             "url": "https://www.denydesigns.com/collections/bench",
#             "data": {
#                 "image_link": "https://www.denydesigns.com/cdn/shop/files/mieken-petra-designs-cozy-halloween-bench-whitebg-gold_large.jpg?v=1719942721",
#                 "product_name": "Mieken Petra Designs Cozy Halloween Bench",
#                 "product_price": "$349.00",
#                 "product_listing_link": "https://www.denydesigns.com/products/mieken-petra-designs-cozy-halloween-bench"
#             },
#             "created_at": "2024-07-13 00:53:43.712066"
#         }
#     ],
#     "errors": []
# }
